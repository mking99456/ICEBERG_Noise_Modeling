# %%
from fileprocess import fileprocess as file

myfilename = '/home/poshu/Downloads/iceberg_9055.root'
data_arr, time_arr, channel_arr = file.getADC(myfilename)
# Out:
# Number of events with data: 38
# Num Channels: 1024 Waveform Length: 2128

# %%
from clockmask import clockmask

masked_data = clockmask.masksignals(data_arr)
# Out:
# pre-mask max std: 377.30591525690375
# pre-mask mean std: 150.0245472582301
# starting event number: 0
# starting event number: 2
# starting event number: 4
# starting event number: 6
# starting event number: 8
# starting event number: 10
# starting event number: 12
# starting event number: 14
# starting event number: 16
# starting event number: 18
# starting event number: 20
# starting event number: 22
# starting event number: 24
# starting event number: 26
# starting event number: 28
# starting event number: 30
# starting event number: 32
# starting event number: 34
# starting event number: 36
# post-mask max std: 56.75115746852879
# post-mask mean std: 9.241404813572297

# %%
from twodhist import twodhist as hist

hist.histAvgASD(masked_data, 200)

# %%
from planesorter import planesorter as sorter
from twodhist import twodhist as hist

sorteddata = sorter.sortdata(masked_data, channel_arr)
midlines = hist.HistASDbyPlane(sorteddata,200)
