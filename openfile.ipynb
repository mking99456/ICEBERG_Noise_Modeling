# %%
import numpy as np
from twodhist import twodhist as hist
numtpcs = 2
numplanes = 3
numchannels = 1024
maxwires = 240
minwvfm = 2128
ASDlength = 1065 #the length of the ASD of the minwvfm
SampleSpacing = 0.5e-6
myarray = np.load('/dune/app/users/poshung/jupyter_scripts/MultiRunData.npz')
#arr_0 = asds #arr_1 = psds #arr_2 = total events #arr_3 = noskips
print("Total Events: "+ str(myarray['arr_2']))
print("Total Channels Analyzed: " + str(np.sum(myarray['arr_3'])))
hist.HistAvgASDbyPlane(myarray['arr_1'],numtpcs,numplanes,maxwires,minwvfm,SampleSpacing)
hist.HistAvgASDbyPlane(myarray['arr_0'],numtpcs,numplanes,maxwires,minwvfm,SampleSpacing)
# Out:
# Total Events: 780
# Total Channels Analyzed: 798720
